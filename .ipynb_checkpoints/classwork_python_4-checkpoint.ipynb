# %% [markdown]
# ## this is checking for div branch working or not

# %%
print('hello python ')
# Out:
# hello python

# %%
'''
- upper

- lower

- title

- capitalize

- casefold

- center

- rstrip

- lstrip

- strip

- startswith

- endswith '''

# %%
str1 = 'pyhton is easy'
str1.upper()
# Out:
# 'PYHTON IS EASY'

# %%
str1.lower()
# Out:
# 'pyhton is easy'

# %%
str1.capitalize()
# Out:
# 'Pyhton is easy'

# %%
str1.casefold()
# Out:
# 'pyhton is easy'

# %%
str1.title()
# Out:
# 'Pyhton Is Easy'

# %%
str1.center(20)
# Out:
# '   pyhton is easy   '

# %%
str1.center(20,'*')
# Out:
# '***pyhton is easy***'

# %%
str2 = '   python    '
str2 ,str2.strip(),str2.lstrip(),str2.rstrip()
# Out:
# ('   python    ', 'python', 'python    ', '   python')

# %%
str3 = '   python***'
str3,str3.strip().strip('*'),str3.rstrip('*'),str3.lstrip()
# Out:
# ('   python***', 'python', '   python', 'python***')

# %%
str4 = 'python is very good language'
str4.startswith('python',0,6)
# Out:
# True

# %%
str4 = 'python is very good language'
str4.startswith('is',7,28)
# Out:
# True

# %%
str5 = 'python is very good language'
str5.endswith('language',8,28)
# Out:
# False

# %%
str5 = 'python is very good language'
str5.endswith('language',1,28)
# Out:
# True
